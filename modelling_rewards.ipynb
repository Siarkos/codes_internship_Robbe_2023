# %%
import numpy as np
import matplotlib.pyplot as plt
import math

time_quarter = 0.25
time_exploration = 3
first_free_reward = 7
xvalues = np.arange(0, 30, 0.05)
slope = 1 #the slope does not work yet, do not change


time_before_true_beginning = time_exploration + time_quarter * first_free_reward

yvalues = [0 if x < time_exploration else int((x - time_exploration)/time_quarter) if x <= time_before_true_beginning else first_free_reward + int(((1 + 8 * (x - time_before_true_beginning)/time_quarter)** 0.5 - 1)/2) for x in xvalues]

plt.plot(xvalues, yvalues)

# t = SLOPE * (x) # [SLOPE] more turns than the previous one are requiered to get the reward 
#         if t > PLATEAU : t = PLATEAU

# %%
math.log(1 + (x - time_exploration)/time_quarter)
# Out:
# 0.0
